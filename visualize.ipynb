# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats

df = pd.read_csv('csv/60.csv', delimiter=',')
df.head()
# Out:
#    Dem/Ind Prob  GOP Prob  GOP Senators Number  GOP Senators  GOP Majority
# 0          0.05      0.05                53.15            53             3
# 1          0.05      0.10                52.73            53             3
# 2          0.05      0.15                52.45            52             2
# 3          0.05      0.20                51.88            52             2
# 4          0.05      0.25                51.51            52             2

# %%
dicts = df.to_dict('records')
print(dicts[:5])
# Out:
# [{'Dem/Ind Prob': 0.05, 'GOP Prob': 0.05, 'GOP Senators Number': 53.15, 'GOP Senators': 53, 'GOP Majority': 3}, {'Dem/Ind Prob': 0.05, 'GOP Prob': 0.1, 'GOP Senators Number': 52.73, 'GOP Senators': 53, 'GOP Majority': 3}, {'Dem/Ind Prob': 0.05, 'GOP Prob': 0.15, 'GOP Senators Number': 52.45, 'GOP Senators': 52, 'GOP Majority': 2}, {'Dem/Ind Prob': 0.05, 'GOP Prob': 0.2, 'GOP Senators Number': 51.88, 'GOP Senators': 52, 'GOP Majority': 2}, {'Dem/Ind Prob': 0.05, 'GOP Prob': 0.25, 'GOP Senators Number': 51.51, 'GOP Senators': 52, 'GOP Majority': 2}]

# %%
sns.relplot(x="Dem/Ind Prob", y="GOP Prob", hue="GOP Majority", size="GOP Majority", sizes=(15,300), data=df)
